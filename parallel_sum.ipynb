# %%
import numpy as np
from tqdm.notebook import tqdm
import data_loader
import mps_func
import skimage.measure
import pickle
import time

# %%
def timeit(func):
    def inner(*args, **kwargs):
        t0 = time.time()
        result = func(*args, **kwargs)
        print('duration of "{}": {}'.format(func.__name__, time.time() - t0))
        return result

    return inner

class DataProcessing:

    def __init__(self, dataset, max_nb_images=None):
        """
        images_dict: size=(10, # of digits (~4968)
        """


        self.max_nb_images = max_nb_images
        self.original_images, self.labels = dataset

        self.images = self.mean_pooling(self.original_images, 2)
        self.images_dict = self.separate_digits(self.images, self.labels)

    @staticmethod
    def flat_to_2d(batch):
        H = W = int(np.sqrt(batch.shape[-1]))
        assert H * W == batch.shape[-1]
        return batch.reshape((-1, H, W))

    @staticmethod
    def square_to_flat(batch):
        H = batch.shape[-1]
        return batch.reshape((-1, H ** 2))

    def mean_pooling(self, images_, filter_size):
        images_2d = self.flat_to_2d(images_)
        pooled_image = skimage.measure.block_reduce(images_2d, (1, filter_size, filter_size), np.mean)
        return self.square_to_flat(pooled_image)

    @staticmethod
    def separate_digits(images, labels):
        images_dict = {}
        for label in range(10):
            images_dict[label] = images[labels == [label]]

        return images_dict


class MPS_model:
    def __init__(self, images_dict, chi):
        self.images_dict = images_dict
        self.chi = chi
        self.mps_dict = self.create_mps_dict_iter(chi)
        # Each mps from mps_dict[digit] is the full mps of that digits

        return

    def create_mps_dict(self):
        """
        This function create the exact MPS of the whole dataset.
        This is inefficient.
        """
        mps_dict = {}
        for label in self.images_dict.keys():
            images = self.images_dict[label]  # (num_data, num_pixels)
            num_data, num_pixels = images.shape
            phi_x = self.local_feature_map(images).transpose([1, 2, 0])  # [num_pixels, phys_dim, num_data]
            num_pixels, phys_dim, num_data = phi_x.shape

            expanded = np.zeros(phi_x.shape + phi_x.shape[-1:], dtype=phi_x.dtype)
            # [num_pixels, phys_dim, num_data, num_data]
            diagonals = np.diagonal(expanded, axis1=-2, axis2=-1)
            diagonals.setflags(write=True)
            diagonals[:] = phi_x

            mps_phi_x = [tensor for tensor in (expanded.transpose([0, 2, 1, 3]))[:]]
            # [num_data, phys_dim, num_data]
            one_vec = np.ones([num_data, 1])
            mps_phi_x[0] = np.tensordot(one_vec, mps_phi_x[0], [[0], [0]])
            mps_phi_x[-1] = np.tensordot(mps_phi_x[-1], one_vec, [[2], [0]])

            mps_dict[label] = mps_phi_x

        return mps_dict

    def create_mps_dict_iter(self, chi):
        mps_dict = {}
        for label in self.images_dict.keys():
            images = self.images_dict[label]  # (num_data, num_pixels)
            num_data, num_pixels = images.shape

            images_iter_list = (images[idx * chi: (idx + 1) * chi] for idx in
                                range(np.ceil(num_data / chi).astype(int))) # minibatch of chi number of images
            mps_iter_list = []
            for batch_images in tqdm.tqdm(images_iter_list):
                phi_x = self.local_feature_map(batch_images).transpose([1, 2, 0])  # [num_pixels, phys_dim, num_data(=chi)]
                num_pixels, phys_dim, num_batch_data = phi_x.shape

                expanded = np.zeros(phi_x.shape + phi_x.shape[-1:], dtype=phi_x.dtype) # [num_pixels, phys_dim, num_data, num_data]
                # [num_pixels, phys_dim, num_batch_data, num_batch_data]
                diagonals = np.diagonal(expanded, axis1=-2, axis2=-1)
                diagonals.setflags(write=True) #??
                diagonals[:] = phi_x

                mps_phi_x = [tensor for tensor in (expanded.transpose([0, 2, 1, 3]))[:]]
                # [num_pixels, num_data, phys_dim, num_batch_data]
                one_vec = np.ones([num_batch_data, 1])
                mps_phi_x[0] = np.tensordot(one_vec, mps_phi_x[0], [[0], [0]])
                mps_phi_x[-1] = np.tensordot(mps_phi_x[-1], one_vec, [[2], [0]])
                mps_phi_x, trunc_err = mps_func.right_canonicalize(mps_func.lpr_2_plr(mps_phi_x))
                mps_phi_x = mps_func.plr_2_lpr(mps_phi_x)
                mps_iter_list.append(mps_phi_x)
            print(len(mps_iter_list), len(mps_iter_list[0]))
            while (len(mps_iter_list) > 1):
                print("new iter")
                for mm in mps_iter_list:
                    print(mm[50].shape)

                new_mps_iter_list = []

                for iter_idx in range(len(mps_iter_list) // 2):
                    mps1 = mps_iter_list[iter_idx * 2 + 0]
                    mps2 = mps_iter_list[iter_idx * 2 + 1]

                    new_mps = mps_func.addition_MPS_compression_variational([t.copy() for t in mps1], mps1, mps2,
                                                                            verbose=0)
                    new_mps_iter_list.append(new_mps)

                if len(mps_iter_list) % 2 != 0:
                    mps_iter_list[-1][-1] = mps_iter_list[-1][-1] * 0.5
                    new_mps_iter_list.append(mps_iter_list[-1])

                mps_iter_list = new_mps_iter_list
            assert len(mps_iter_list) == 1
            mps_dict[label] = mps_iter_list[0]

        return mps_dict

    @staticmethod
    def local_feature_map(X):
        return np.stack([np.cos(X * np.pi / 2), np.sin(X * np.pi / 2)], axis=-1)

# %%
training_data, val_data, test_data = data_loader.load_data('data/mnist.pkl.gz')

print("loaded")

pooled_training_data = DataProcessing(training_data)
pooled_val_data = DataProcessing(val_data)
pooled_test_data = DataProcessing(test_data)



print(len(images_iter_list), len(images_iter_list[0]))
print("pooled")

for chi in [5, 40, 50]:
    model = MPS_model(pooled_training_data.images_dict, chi=chi)
    break
#     break
#     pickle.dump(model.mps_dict, open('/tuph/t30/space/ga63zuh/qTEBD/sampling_mps/training_chi%d.pkl' % chi, 'wb'))
# Out:
# loaded
# 3it [00:00, 27.85it/s]
# 329 15
# pooled
# 987it [00:37, 26.44it/s]
# 987 196
# new iter
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (2, 2, 2)
# new iter
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (5, 2, 5)
# (2, 2, 2)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-abf9fae152cf> in <module>
#      13
#      14 for chi in [5, 40, 50]:
# ---> 15     model = MPS_model(pooled_training_data.images_dict, chi=chi)
#      16     break
#      17 #     break
#
# <ipython-input-41-d548d0afc695> in __init__(self, images_dict, chi)
#      51         self.images_dict = images_dict
#      52         self.chi = chi
# ---> 53         self.mps_dict = self.create_mps_dict_iter(chi)
#      54         # Each mps from mps_dict[digit] is the full mps of that digits
#      55
#
# <ipython-input-41-d548d0afc695> in create_mps_dict_iter(self, chi)
#     123                     mps2 = mps_iter_list[iter_idx * 2 + 1]
#     124
# --> 125                     new_mps = mps_func.addition_MPS_compression_variational([t.copy() for t in mps1], mps1, mps2,
#     126                                                                             verbose=0)
#     127                     new_mps_iter_list.append(new_mps)
#
# ~\Documents_no_sync\MPS-MNIST\mps_func.py in addition_MPS_compression_variational(mps_comp, mps_target_1, mps_target_2, max_iter, tol, verbose)
#     395             left_env_1 = einsum('ij,ikl->jkl', left_env_1,
#     396                                 mps_comp[site].conjugate())
# --> 397             left_env_1 = einsum('ijk,ijl->kl', left_env_1, mps_target_1[site])
#     398             cache_env_list_1[site] = left_env_1
#     399             cache_env_list_1[site + 1] = None
#
# KeyboardInterrupt:
